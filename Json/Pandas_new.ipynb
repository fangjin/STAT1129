# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# **Lables**
#
#
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
# With the index argument, you can name your own labels.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# Create a simple Pandas Series from a dictionary:

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# Example
# Create a Series using only data from "day1" and "day2":

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
mydictionary = {
           "A": 1.0,
           "B": pd.Timestamp("20130102"),
           "C": pd.Series(1, index=list(range(6)), dtype="float32"),
           "D": np.array([3] * 6, dtype="int32"),
           "E": pd.Categorical(["test", "train","test", "train","test", "train"]),
           "F": "foo",
           }

df2 = pd.DataFrame( mydictionary )
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# 4  1.0 2013-01-02  1.0  3   test  foo
# 5  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import pandas as pd

mydic = {'James': ['A', 'B'], 'Amy': ['B','C'] }

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydic)

print(myvar)
# Out:
#   James Amy
# 0     A   B
# 1     B   C

# %% [markdown]
# **What is a Series?**
#
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
import pandas as pd

a = [1, 7, 2, 'string', 5.5]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0         1
# 1         7
# 2         2
# 3    string
# 4       5.5
# dtype: object

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# add index yourself

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# Selection

# %%
print(df.loc["day3"])
# Out:
# calories    390
# duration     45
# Name: day3, dtype: int64

# %%
#refer to the named index:
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.300628 -0.830687  2.285091 -1.911657
# 2013-01-02 -2.681371 -0.005502  1.229834  1.036436
# 2013-01-03 -0.454986  0.629028 -0.354252  2.025281

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -2.681371 -0.005502  1.229834  1.036436
# 2013-01-03 -0.454986  0.629028 -0.354252  2.025281
# 2013-01-04 -0.344470  0.692074  0.029931 -0.054738

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/fangjin/STAT1129/main/Json/Iris.csv', encoding='utf-8')

#https://raw.githubusercontent.com/fangjin/STAT1129/main/Json/Iris.csv

df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# **Load Files Into a DataFrame**
#
# If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#Load the JSON file into a DataFrame:

import pandas as pd

#df = pd.read_json('data.json')
df = pd.read_json('https://raw.githubusercontent.com/fangjin/STAT1129/main/Json/data.json', encoding='utf-8')

#print(df.to_string()) 
df["Duration"]
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
#        ..
# 164    60
# 165    60
# 166    60
# 167    75
# 168    75
# Name: Duration, Length: 169, dtype: int64

# %%
import pandas as pd
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  }
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse
# 0        60    110       130
# 1        60    117       145
# 2        60    103       135
# 3        45    109       175
# 4        45    117       148
# 5        60    102       127

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
import pandas as pd

#fruits = pd.read_table('./fruit_data_with_colors.txt')
fruits1 = pd.read_table('https://raw.githubusercontent.com/fangjin/STAT1129/main/Json/fruit_data_with_colors.txt', encoding='utf-8')
fruits1
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
import matplotlib.pyplot as plt
print(fruits1.shape)
# Out:
# (59, 7)

# %%
print(fruits1['fruit_name'].unique())
# Out:
# ['apple' 'mandarin' 'orange' 'lemon']

# %%
print(fruits1.groupby('fruit_name').size())
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64

# %%
import seaborn as sns
sns.countplot(fruits1['fruit_name'],label="Count")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
